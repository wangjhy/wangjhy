# %% [markdown]
# Expected Output
# By the end of this mini project, you will need to deliver within your code:
# The count of the tuples in the given dataset.
# The count of the names of unique tournament names from the attributes.
# The count of matches in 2018 from the attributes.
# The count of wins, losses, or draws given in the data columns.
# An output plot of the pie chart of the wins, losses, or draws.
# An output plot of the pie chart of the neutral column in the input dataset.
# The count of the names of unique team names from the attributes.
# You are expected to write around 30 lines of code to complete this project

# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#              date  home_team  away_team  home_score  away_score  \
# 0      1872-11-30   Scotland    England           0           0
# 1      1873-03-08    England   Scotland           4           2
# 2      1874-03-07   Scotland    England           2           1
# 3      1875-03-06    England   Scotland           2           2
# 4      1876-03-04   Scotland    England           3           0
# ...           ...        ...        ...         ...         ...
# 42645  2021-09-09   Colombia      Chile           3           1
# 42646  2021-09-09   Paraguay  Venezuela           2           1
# 42647  2021-09-09    Uruguay    Ecuador           1           0
# 42648  2021-09-09  Argentina    Bolivia           3           0
# 42649  2021-09-09     Brazil       Peru           2           0
#
#                          tournament          city    country  neutral
# 0                          Friendly       Glasgow   Scotland    False
# 1                          Friendly        London    England    False
# 2                          Friendly       Glasgow   Scotland    False
# 3                          Friendly        London    England    False
# 4                          Friendly       Glasgow   Scotland    False
# ...                             ...           ...        ...      ...
# 42645  FIFA World Cup qualification  Barranquilla   Colombia    False
# 42646  FIFA World Cup qualification      Asunción   Paraguay    False
# 42647  FIFA World Cup qualification    Montevideo    Uruguay    False
# 42648  FIFA World Cup qualification  Buenos Aires  Argentina    False
# 42649  FIFA World Cup qualification        Recife     Brazil    False
#
# [42650 rows x 9 columns]

# %%
df2 = df.dropna()

# %%
#no missing values
df2
# Out:
#              date  home_team  away_team  home_score  away_score  \
# 0      1872-11-30   Scotland    England           0           0
# 1      1873-03-08    England   Scotland           4           2
# 2      1874-03-07   Scotland    England           2           1
# 3      1875-03-06    England   Scotland           2           2
# 4      1876-03-04   Scotland    England           3           0
# ...           ...        ...        ...         ...         ...
# 42645  2021-09-09   Colombia      Chile           3           1
# 42646  2021-09-09   Paraguay  Venezuela           2           1
# 42647  2021-09-09    Uruguay    Ecuador           1           0
# 42648  2021-09-09  Argentina    Bolivia           3           0
# 42649  2021-09-09     Brazil       Peru           2           0
#
#                          tournament          city    country  neutral
# 0                          Friendly       Glasgow   Scotland    False
# 1                          Friendly        London    England    False
# 2                          Friendly       Glasgow   Scotland    False
# 3                          Friendly        London    England    False
# 4                          Friendly       Glasgow   Scotland    False
# ...                             ...           ...        ...      ...
# 42645  FIFA World Cup qualification  Barranquilla   Colombia    False
# 42646  FIFA World Cup qualification      Asunción   Paraguay    False
# 42647  FIFA World Cup qualification    Montevideo    Uruguay    False
# 42648  FIFA World Cup qualification  Buenos Aires  Argentina    False
# 42649  FIFA World Cup qualification        Recife     Brazil    False
#
# [42650 rows x 9 columns]

# %%
len(df)
# Out:
# 42650

# %%
df["tournament"]
# Out:
# 0                            Friendly
# 1                            Friendly
# 2                            Friendly
# 3                            Friendly
# 4                            Friendly
#                      ...
# 42645    FIFA World Cup qualification
# 42646    FIFA World Cup qualification
# 42647    FIFA World Cup qualification
# 42648    FIFA World Cup qualification
# 42649    FIFA World Cup qualification
# Name: tournament, Length: 42650, dtype: object

# %%
len(df[df.date == 2018])
# Out:
# 0

# %%
import numpy as np
import datetime as dt

df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year

# %%
len(df[df.year == 2018])
# Out:
# 908

# %%
df3 = df[["home_score","away_score"]]

# %%
df4 = df.home_score-df.away_score
net_score = df4.values

# %%
win = np.sum(net_score>0)

# %%
draw = np.sum(net_score==0)

# %%
lost = np.sum(net_score<0)

# %%
import matplotlib.pyplot as plt

# %%
results = ["win", "draw", "lost"]
numbers = [win, draw, lost]
plt.pie(numbers, labels = results)
# Out:
# ([<matplotlib.patches.Wedge at 0x18025b7c248>,
#   <matplotlib.patches.Wedge at 0x18025b58d08>,
#   <matplotlib.patches.Wedge at 0x18025b7c508>],
#  [Text(0.04746637221253046, 1.0989754062348174, 'win'),
#   Text(-0.8834453006781248, -0.655381111041307, 'draw'),
#   Text(0.6928924638279437, -0.8543418716008493, 'lost')])

# %%
plt.pie(df.neutral.values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-d06add1a9018> in <module>
# ----> 1 plt.pie(df.neutral.values)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2785         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2786         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2787         data is not None else {}))
#    2788
#    2789
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    3027                                **wedgeprops)
#    3028             slices.append(w)
# -> 3029             self.add_patch(w)
#    3030             w.set_label(label)
#    3031
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    1968         self._set_artist_props(p)
#    1969         if p.get_clip_path() is None:
# -> 1970             p.set_clip_path(self.patch)
#    1971         self._update_patch_limits(p)
#    1972         self.patches.append(p)
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     730             if isinstance(path, Rectangle):
#     731                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 732                                                path.get_transform())
#     733                 self._clippath = None
#     734                 success = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     212         to the :class:`Patch`.
#     213         """
# --> 214         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     215
#     216     def get_data_transform(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     756
#     757     def get_patch_transform(self):
# --> 758         self._update_patch_transform()
#     759         return self._rect_transform
#     760
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     735         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     736         rot_trans = transforms.Affine2D()
# --> 737         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     738         self._rect_transform = transforms.BboxTransformTo(bbox)
#     739         self._rect_transform += rot_trans
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    1958         # Cast to float to avoid wraparound issues with uint8's
#    1959         x, y = float(x), float(y)
# -> 1960         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1961
#    1962     def translate(self, tx, ty):
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in translate(self, tx, ty)
#    1970         translate_mtx = np.array(
#    1971             [[1.0, 0.0, tx], [0.0, 1.0, ty], [0.0, 0.0, 1.0]], float)
# -> 1972         self._mtx = np.dot(translate_mtx, self._mtx)
#    1973         self.invalidate()
#    1974         return self
#
# KeyboardInterrupt:

# %%
df.neutral.values
# Out:
# array([False, False, False, ..., False, False, False])

# %%
df.neutral.describe().transpose()
# Out:
# count     42650
# unique        2
# top       False
# freq      32076
# Name: neutral, dtype: object

# %%
pd.unique(df.neutral)
# Out:
# array([False,  True])

# %%
plt.pie(df.groupby(["neutral"]).count()["date"])
# Out:
# ([<matplotlib.patches.Wedge at 0x180551cb688>,
#   <matplotlib.patches.Wedge at 0x180551cbac8>],
#  [Text(-0.7828713770530386, 0.7727304879394103, ''),
#   Text(0.7828713408789129, -0.7727305245882636, '')])

# %%
df.groupby(["neutral"]).size().plot.pie()

# %%
df5.plot.pie()

# %%
print (df5)
# Out:
# neutral
# False    32076
# True     10574
# dtype: int64

# %%
len(df.home_team.unique())
# Out:
# 308

# %%
len(df.away_team.unique())
# Out:
# 306

# %%
df4 = df["home_team"]

# %%
df5 = df["away_team"]

# %%
final = df4.append(df5)

# %%
len(final.unique())
# Out:
# 313

# %%
len(df.city.unique())
# Out:
# 2051

# %%
len(df.tournament.unique())
# Out:
# 120
